# %%
# Import Lib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import csv
import seaborn as sns

from sklearn import datasets
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.svm import SVC
import matplotlib.pylab as plt
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
import pickle
import pandas as pd
import numpy as np
# Read data
#from reactionrnn import reactionrnn
import re
from keras.layers import Embedding

dataset = pd.read_csv('Final/final_videos.csv')
dataset = dataset.drop(dataset.columns[0], axis=1)
dataset

from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
# Label Encoder

## Label encoder mapping value

user_mapping={
'這群人TGOP':0,
'滾石唱片 ROCK RECORDS':1,
'相信音樂BinMusic':2,
'阿滴英文':3,
'蔡阿嘎':4,
'阿神':5,
'杰威爾音樂 JVR Music':6,
'眾量級CROWD':7,
'瑪莎與熊 Masha and The Bear CH':8,
'華納音樂 Warner Music Taiwan':9,
'聖結石Saint':10,
'福茂唱片':11,
'華研國際':12,
'小玉':13,
'放火 Louis':14,
'DE JuN':15,
'Joeman':16,
'安啾咪':17,
'人生肥宅x尊':18,
'菜喳':19,
'魚乾':20,
'白癡公主':21,
'WACKYBOYS 反骨男孩':22,
'木曜4超玩':23,
'噪咖EBCbuzz':24,
'我愛貓大':25,
'大日宗':26,
'我愛玩很大':27,
'Vidol TV':28,
'HowFun':29,
'老皮':30,
'舞秋風':31,
'JJ Lin林俊傑':32,
'三原JAPAN Sanyuan_JAPAN':33,
'巧克力':34,
'sandy mandy':35,
'滴妹':36,
'SEANCHOU MUSIC CHANNEL':37,
'我愛大熱門':38,
'在不瘋狂就等死 x…':39,
'the劉沛':40,
'古娃娃WawaKu':41,
'玖壹壹':42,
'Stopkiddinstudio':43,
'counter656':44,
'黃氏兄弟':45,
'蔡阿嘎Life':46,
'啾啾鞋':47,
'Hello Catie':48,
'卡提諾狂新聞':49,
'頑GAME':50,
'MaoMao TV':51,
'最愛,國光幫幫忙':52,
'NyoNyoTV妞妞TV':53,
'聖嫂Dodo':54,
'UNIVERSAL MUSIC TAIWAN 環球音樂':55,
'搞神馬':56,
'鬼鬼':57,
'Taiwan Bar':58,
'Keelong and Rays這群人…':59,
'理科太太 Li Ke Tai Tai':60,
'星培Jasper':61,
'翔麟':62,
'巢哥':63,
'小白':64,
'英雄日常Heroisme':65,
'民視戲劇館':66,
'黃大謙':67,
'腦補給':68,
'含羞草':69,
'Odd Cactus':70,
'Jay Lee Painting & Charlie\'s Vlog':71,
'蠢蠢':72,
'GINA HELLO!':73,
'超粒方':74,
'碰碰狐 (兒童兒歌・故事)':75,
'冏星人':76,
'蔡佩軒 Ariel Tsai':77,
'楊桃美食網':78,
'YOYOTV':79,
'黑男':80,
'小伶玩具 (Xiaoling Toys)':81,
'BuBuChaCha 傳說':82,
'少康戰情室':83,
'人生勝利組Life victory group':84,
'館長成吉思汗':85,
'馬叔叔':86,
'我愛小明星大跟班':87,
'烏鴉DoKa TV':88,
'百變沛莉 Peri':89,
'眾量級CROWDxFUN生活':90,
'台灣達人秀':91,
'加點吉拿棒':92,
'蘇打綠 sodagreen':93,
'JasonChenAsia':199,
'我是RT':200,
'菜喳Live實況台':201,
'閱部客':202,
'B.C.&Lowy':203,
'歐陽娜娜Nana OuYang':204,
'紅月':205,
'92CCDJ':206,
'雞脖子 GNeck':207,
'悟訢':208,
'鍾明軒':209,
'atsukiFE3':210,
'無名':211
}

channel_mapping={
'Entertainment':0,
'Music':1,
'Education':2,
'Games':3,
'Comedy':4,
'Film':5,
'People':6,
'nan':7,
'Travel':8,
'Howto':9,
'News':10,
'Animals':11,
'Sports':12,
'Autos':13,
'Tech':14, 
}

category_mapping={
'Entertainment':0,
'Music':1,
'Comedy':2,
'Nonprofits_and_Activism':3,
'Film_and_Animation':4,
'People_and_Blogs':5,
'Education':6,
'News_and_Politics':7,
'Travel_and_Events':8,
'Science_and_Technology':9,
'Gaming':10,
'Autos_and_Vehicles':11,
'Howto_and_Style':12,
'Sports':13,
'Shows':14,
'Pets_and_Animals':15
}
    
df =pd.read_pickle("dataset_preprocssing.pkl")
df['User_Name'] = df['User_Name'].map(user_mapping)
df['Channel_Type'] = df['Channel_Type'].map(channel_mapping)
df['Category'] = df['Category'].map(category_mapping)
df

corrmat = df.corr()
f, ax = plt.subplots(figsize=(14, 14))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#Label ground truth
label = df['Views']

#features
user_name = df['User_Name']
uploads = df['Uploads']
sub_num = df['Subscribers']
total_video_views = df['Total_Video_Views']
channel_type = df['Channel_Type']
user_exist_day = df['User_Exist_Days']
video_exist_day = df['Video_exist_day']
category = df['Category']
title = df['Title']
keyword_freq = df['Keywords_Freq']


filtered_data = pd.concat([user_name, uploads, sub_num, total_video_views, channel_type, 
                            user_exist_day, video_exist_day, category, keyword_freq, title], axis=1) #, like, df4, dislike, comment
filtered_data
# Out:
#         User_Name  Uploads  Subscribers  Total_Video_Views  Channel_Type  \
# 33467        34.0     2706       910273          429579292           3.0
# 50025        62.0     1999       649569          303891209           3.0
# 160783      201.0     3173       280832           65344441           3.0
# 1522         93.0      299       479234          377546219           1.0
# 124310      136.0     1593       372575          197349623           3.0
# 13423         2.0     1220      2148666         2327133177           1.0
# 160047      201.0     3173       280832           65344441           3.0
# 115717      109.0     3428       427999          132041064           0.0
# 83507         9.0     1700      1422645          914249776           1.0
# 108077       89.0      665       490246           56085904           9.0
# 59770        80.0     1150       523576          187872404           0.0
# 143516      167.0      160       328483           54008179           6.0
# 28301        27.0     1045      1044747          531038313           0.0
# 111295      100.0     2334       453192          223862022           NaN
# 118825      115.0     7804       417135          233369915           0.0
# 95544        66.0     7653       615980         1164843901           0.0
# 145023      173.0       67       324563           24213796           NaN
# 149410      180.0     9618       317568          381151789           6.0
# 26322        25.0     2358      1077713          909858511           0.0
# 156501      191.0     5849       300584          299124612           0.0
# 110761       99.0     1547       457517          189618306          13.0
# 80125       133.0      541       379282          146298677           4.0
# 132065      149.0     8609       358234          171189734           3.0
# 122891      127.0     4460       386484          232808367           3.0
# 27506        26.0      288      1063371          223494883           NaN
# 87825        30.0     2614      1004125          332025433           3.0
# 12435   猴子 飞行员 monkey pilot summer day official music ...
# ...                                                   ...
# 4260         老皮 台 minecraft agrarian skies 空岛 极限 生存 part
# 103593       海豚 想 high 竟会 去 咬 河豚 个 觉得 瞎 但 都 是 真的 世界 小 知识
# 86488                         血尿 再临 黑暗 灵魂 dark souls iii
# 101629  完整版 上集 卜 睿哲 吁川 普派 高官 来 台湾 蔡英文 亲 美国 奏效 害死 台湾 少康...
# 28037                  搞笑 足 垒球 笑 到 长 腹肌 锁定 北海道 玩很大 综艺玩很大
# 81638                          婕 翎 週日 小 废片 你 今天 可以 生小孩 吗
# 82289             拉霸 乐团 slot machine x sony music 西洋 粉丝团
# 170659                       kobieta jednoro ż ec z chin
# 48805            当 个 创世神 minecraft 翔麟 的 牧场 物语 ep 可爱 的 矿坑
# 103683  他 因为 出差 太累 一 上 飞机 就 秒 睡 醒来 发现 小时 路程 他 要 花 天夜 才...
# 125              mxm gone cold 华纳 official hd 高画质 官方 中字版
# 156272      最 经典 的 樱桃 小丸子 精彩 预告 momo 亲子台 每週 一 五 晚上 欢乐 播出
# 82331   詹姆斯 亚瑟 james arthur 说 妳 不会 离开 say you won t le...
# 102790         独派 吴澧培 发动 打 趴柯 p 宁让 国民党 也 不让 柯文哲 连任 少康战情室
# 19424                                   小小 飞轮海 公仔 命名 公 佈
# 31423                                        hob 水利 灌溉 中
# 43339            蔡阿嘎 唱 自己 的 歌 哀凤 siri 侦测 的 出来 吗 蔡阿嘎 life
# 150219                      宝贝 日记 逛 夜市 玩具店 跳跳 鱼 玩 玩具 mvi
# 172992               stardew valley 星露 谷物 语 ep 上 夏季 的 尾巴
# 44863   日本 女仆 咖啡店 不能 做 的 事 在 秋叶原 做错事 メ イ ド カ フ ェ ft 阿伦...
# 165900                          gino 脖子 澳门 美食 大 作战 短剧 系列
# 145870  滚动 鲨鱼 桌上 游戏 我们 在 玩具 反斗 城 找到 的 toysrus 多人 桌游 玩具...
# 99697                    yoyo man 第季 第集 仙人掌 之爱 卡通动画 儿童节目
# 59751            街头 尬 聊王 再次 遇到 超 顶级 美女 希望 以后 跟 她 拍 短剧 ep
# 97966   yoyo 点点 名 三思而后行 彩色 棉花糖 太阳 哥哥 月亮 姐姐 幼幼 儿童节目 hd ...
# 95800                我 的 老师 叫小贺 my teacher is xiao he ep
# 168967  看脸 时代 智障 老板 面试 让 长相 取决 一切 达人秀 x 红逗 联合 出品 原来 你 ...
# 1866    金家好媳妇 第集 wife ep part 又 有 新 角色 了 有财 的 朋友 是 谁 直...
# 80709                     牛叔 分钟 看 深山 遭遇 变异 人 的 恐怖片 致命 弯道
# 80506        牛叔 小 英雄 们 受到 非人 折磨 集体 走火 引爆 邪教 老巢 末日 巡逻队 登场
#
# [158275 rows x 10 columns]

# %%
from gensim.models import word2vec
from sklearn.model_selection import train_test_split

label = df['Views']


# Create word to vector
sentences = []
for single_title in filtered_data['Title'].values:
    sen = []
    split_title = single_title.split(" ")
    for word in split_title:
        if(word != " "):
            sen.append(word)
    sentences.append(sen)

print("Done")
EMBEDDING_DIM = 150
model = word2vec.Word2Vec(sentences, size=EMBEDDING_DIM, window=7, workers=6, min_count=10)

print(len(model.wv.vocab))
print("Done")
# Out:
# Done
# 17118
# Done

# %%
word2idx = {"_PAD": 0} 
vocab_list = [(k, model.wv[k]) for k, v in model.wv.vocab.items()]

embeddings_matrix = np.zeros((len(model.wv.vocab.items()) + 1, model.vector_size))
for i in range(len(vocab_list)):
    word = vocab_list[i][0]
    word2idx[word] = i + 1
    embeddings_matrix[i + 1] = vocab_list[i][1]

EMBEDDING_DIM = 100 #词向量维度
embedding_layer = Embedding(len(embeddings_matrix),
                            EMBEDDING_DIM,
                            weights=[embeddings_matrix],
                            trainable=False)

# %%
# Test the loaded word2vec model in gensim
# We will need the raw vector for a word
#print(model['林俊杰']) 

# We will also need to get the words closest to a word
model.similar_by_word('蔡依林', topn = 15)
# Out:
# /home/tony/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
# [('jolin', 0.9691576957702637),
#  ('tsai', 0.9418920278549194),
#  ('八三', 0.7933571338653564),
#  ('演唱会', 0.7922343015670776),
#  ('孙燕姿', 0.7737436890602112),
#  ('毕书尽', 0.7720851898193359),
#  ('张学友', 0.7703515291213989),
#  ('dino', 0.763766884803772),
#  ('恋习', 0.7624247670173645),
#  ('sun', 0.7610154747962952),
#  ('夭', 0.75929194688797),
#  ('玉玺', 0.7510433197021484),
#  ('呸', 0.7500727772712708),
#  ('muse', 0.7498989105224609),
#  ('yan', 0.7491582632064819)]

# %%
from sklearn.manifold import TSNE
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif']=['SimHei']
plt.figure(figsize=(15, 15),)
def display_closestwords_tsnescatterplot(model, word):
    
    arr = np.empty((0,150), dtype='f')
    word_labels = [word]

    # get close words 
    close_words = model.similar_by_word(word, topn=100)
    
    # add the vector for each of the closest words to the array
    arr = np.append(arr, np.array([model[word]]), axis=0)
    for wrd_score in close_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
        
    # find tsne coords for 2 dimensions
    tsne = TSNE(n_components=2, random_state=0)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)

    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    # display scatter plot
    plt.scatter(x_coords, y_coords)

    num = 0
    for label, x, y in zip(word_labels, x_coords, y_coords):
        num += 1
        if num <= 10:
            plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points', fontsize=12, color='red')
        else:
            plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points', fontsize=12, color='blue')

    plt.xlim(x_coords.min()+0.005, x_coords.max()+0.005)
    plt.ylim(y_coords.min()+0.005, y_coords.max()+0.005)
    plt.show()
display_closestwords_tsnescatterplot(model, '史上')
# Out:
# /home/tony/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   # This is added back by InteractiveShellApp.init_path()
# /home/tony/anaconda3/envs/py36/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# /home/tony/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /home/tony/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   app.launch_new_instance()
