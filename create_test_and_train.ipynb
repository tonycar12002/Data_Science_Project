# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import csv

# %%
path = "/home/tony/Downloads/"
dataset = pd.read_csv(path + "all_videos.csv")
dataset
# Out:
#        User_Name                                               Link  Uploads  \
# 0        這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# 1        這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# 2        這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# 3        這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# 4        這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# 5        這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# 6        這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# 7        這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# 8        這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# 9        這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# 10       這群人TGOP  https://youtube.com/channel/UC6FcYHEm7SO1jpu5T...      178
# ...

# %%
train, test = train_test_split(dataset, test_size=0)

train.to_csv(path + 'train.csv')
test.to_csv(path + 'test.csv')

# %%
text_file = open(path + "title_all.txt", "w")
for title in train['Title']:
    text_file.write(title + "\n")
text_file.close()
